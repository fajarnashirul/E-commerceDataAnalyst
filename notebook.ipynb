# %% [markdown]
# # **Proyek Analisis Data: Nama dataset**
# * Nama: Fajar Nashirul Haq
# * Email: fajarnashirul@gmail.com
# * Id Dicoding:

# %% [markdown]
# # **Menentukan Pertanyaan Bisnis**
# 1. pertanyaan 1
# 2. pertanyaan 2

# %% [markdown]
# # **Menyiapkan semua library yang dibutuhkan**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as slt

# %% [markdown]
# # **Data Wrangling**
# ## Gathering Data

# %%
customers_dataset_df = pd.read_csv('data/customers_dataset.csv')
customers_dataset_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geolocation_df = pd.read_csv('data/geolocation_dataset.csv')
geolocation_df
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
orders_dataset_df = pd.read_csv('data/orders_dataset.csv')
orders_dataset_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
order_items_df = pd.read_csv('data/order_items_dataset.csv')
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_payments_df = pd.read_csv('data/order_payments_dataset.csv')
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_reviews_df = pd.read_csv('data/order_reviews_dataset.csv')
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
products_dataset_df = pd.read_csv('data/products_dataset.csv')
products_dataset_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
product_category_df = pd.read_csv('data/product_category_name_translation.csv')
product_category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
sellers_dataset_df = pd.read_csv('data/sellers_dataset.csv')
sellers_dataset_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ## Assessing Data

# %%
print(customers_dataset_df.info())
customers_dataset_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
# None
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# ...

# %%
print(customers_dataset_df.isna().sum())
customers_dataset_df.duplicated().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
# 0

# %%
print(geolocation_df.info())
geolocation_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB
# None
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                  1.000163e+06     1.000163e+06     1.000163e+06
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# ...

# %%
print(geolocation_df.isna().sum())
geolocation_df.duplicated().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
# 261831

# %%
print(orders_dataset_df.info())
orders_dataset_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
# None
#                                 order_id                       customer_id  \
# count                              99441                             99441
# ...

# %%
print(orders_dataset_df.isna().sum())
orders_dataset_df.duplicated().sum()
# filtered_df = orders_dataset_df[orders_dataset_df.order_status == 'delivered']
# filtered_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
# 0

# %%
print(order_payments_df.info())
order_payments_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB
# None
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# ...

# %%
print(order_payments_df.isna().sum())
order_payments_df['order_id'].duplicated().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
# 4446

# %%
order_items_df[order_items_df['order_id'].duplicated()]
# Out:
#                                 order_id  order_item_id  \
# 14      0008288aa423d2a3f00fcb17cd7d8719              2
# 33      00143d0f86d6fbd9f9b38ab440ac16f5              2
# 34      00143d0f86d6fbd9f9b38ab440ac16f5              3
# 43      001ab0a7578dd66cd4b0a71f5b6e1e41              2
# 44      001ab0a7578dd66cd4b0a71f5b6e1e41              3
# ...                                  ...            ...
# 112617  ffecd5a79a0084f6a592288c67e3c298              3
# 112635  fff8287bbae429a99bb7e8c21d151c41              2
# 112641  fffb9224b6fc7c43ebb0904318b10b5f              2
# 112642  fffb9224b6fc7c43ebb0904318b10b5f              3
# 112643  fffb9224b6fc7c43ebb0904318b10b5f              4
#
#                               product_id                         seller_id  \
# 14      368c6c730842d78016ad823897a372db  1f50f920176fa81dab994f9023523100
# 33      e95ee6822b66ac6058e2e4aff656071a  a17f621c590ea0fab3d5d883e1630ec6
# ...

# %%
print(order_items_df.info())
order_items_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB
# None
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# ...

# %%
print(order_items_df.isna().sum())
order_items_df.duplicated().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
# 0

# %%
print(order_reviews_df.info())
order_reviews_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB
# None
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# ...

# %%
print(order_reviews_df.isna().sum())
order_reviews_df.duplicated().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64
# 0

# %%
print(products_dataset_df.info())
products_dataset_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB
# None
#                               product_id product_category_name  \
# count                              32951                 32341
# ...

# %%
print(products_dataset_df.isna().sum())
products_dataset_df.duplicated().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
# 0

# %%
print(product_category_df.info())
product_category_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB
# None
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
print(product_category_df.isna().sum())
product_category_df.duplicated().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64
# 0

# %%
print(sellers_dataset_df.info())
sellers_dataset_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB
# None
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# ...

# %%
print(sellers_dataset_df.isna().sum())
sellers_dataset_df.duplicated().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64
# 0

# %% [markdown]
# ## Cleaning Data

# %%
# #menghapus kolom customer_unique_id pada customer_dataset
# customers_dataset_df = customers_dataset_df.drop(columns=['customer_unique_id'], axis=1)
# customers_dataset_df.head()

# %%
#menghapus kolom geolocation_city dan geolocation_state 
geolocation_df = geolocation_df.drop(columns=['geolocation_city', 'geolocation_state'], axis=1)
#mengahapus data duplikat pada geolocation_df
geolocation_df.drop_duplicates(inplace=True)
print('data duplikat:', geolocation_df.duplicated().sum())
geolocation_df.head()
# Out:
# data duplikat: 0
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607

# %%
#mengubah jenis data menjadi date_time pada orders_dataset
datetime_columns = ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']

for column in datetime_columns:
    orders_dataset_df[column] = pd.to_datetime(orders_dataset_df[column])

orders_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
orders_dataset_df.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# count         99441                          99441
# ...

# %%
#terdapat nilai null pada order_approved_at, sehingga perlu di isi dengan mencari rata-rata waktu approve
order_approved_time = orders_dataset_df['order_approved_at'] - orders_dataset_df['order_purchase_timestamp']
order_approved_time = order_approved_time.apply(lambda x: x.total_seconds())
orders_dataset_df['order_approved_time'] = order_approved_time.round()

print('rata-rata waktu approved:', orders_dataset_df.order_approved_time.mean())
# Out:
# rata-rata waktu approved: 37508.73948691089

# %%
#mengisi data kosong pada order_approved_at dengan menambah order_purchase_timestamp dengan rata-rata waktu approved
orders_dataset_df['order_approved_at'] = orders_dataset_df['order_approved_at'].fillna(
    orders_dataset_df['order_purchase_timestamp'] + pd.to_timedelta(orders_dataset_df.order_approved_time.mean().round(), unit='s'))

#mengupdate kembali order_approved_time setelah semua data terisi
orders_dataset_df['order_approved_time'] = order_approved_time.round()
orders_dataset_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   0
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# order_approved_time               160
# dtype: int64

# %%
'''
pada orders_dataset_df kolom order_delivered_carrier_date dan order_delivered_customer_date,
dengan asumsi bahwa hanya order dengan status 'delivered' yang semua kolomnya perlu diisi
'''
filtered_df = orders_dataset_df[orders_dataset_df.order_status == 'delivered']
filtered_df.isna().sum()
# Out:
# order_id                          0
# customer_id                       0
# order_status                      0
# order_purchase_timestamp          0
# order_approved_at                 0
# order_delivered_carrier_date      2
# order_delivered_customer_date     8
# order_estimated_delivery_date     0
# order_approved_time              14
# dtype: int64

# %%
#pada order_delivered_customer_date yang kosong akan diisi dengan menyesuaikan order_estimated_delivered_date
orders_dataset_df.loc[orders_dataset_df['order_status'] == 'delivered', 'order_delivered_customer_date'] = orders_dataset_df.loc[orders_dataset_df['order_status'] == 'delivered', 'order_delivered_customer_date'].fillna(orders_dataset_df['order_estimated_delivery_date'])

orders_dataset_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   0
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2957
# order_estimated_delivery_date       0
# order_approved_time               160
# dtype: int64

# %%
#melihat data order_status delivered yang memiliki order_delivered_carrier null
filtered_df = orders_dataset_df[orders_dataset_df.order_status == 'delivered']
filtered_df[filtered_df.isna().any(axis=1)]
# Out:
#                                order_id                       customer_id  \
# 5323   e04abd8149ef81b95221e88f6ed9ab6a  2127dc6603ac33544953ef05ec155771
# 16567  8a9adc69528e1001fc68dd0aaebbb54a  4c1ccc74e00993733742a3c786dc3c1f
# 19031  7013bcfc1c97fe719a7b5e05e61c12db  2941af76d38100e0f8740a374f1a5dc3
# 22663  5cf925b116421afa85ee25e99b4c34fb  29c35fc91fc13fb5073c8f30505d860d
# 23156  12a95a3c06dbaec84bcfb0e2da5d228a  1e101e0daffaddce8159d25a8e53f2b2
# 26800  c1d4211b3dae76144deccd6c74144a88  684cb238dc5b5d6366244e0e0776b450
# 38290  d69e5d356402adc8cf17e08b5033acfb  68d081753ad4fe22fc4d410a9eb1ca01
# 39334  d77031d6a3c8a52f019764e68f211c69  0bf35cac6cc7327065da879e2d90fae8
# 48401  7002a78c79c519ac54022d4f8a65e6e8  d5de688c321096d15508faae67a27051
# 61743  2eecb0d85f281280f79fa00f9cec1a95  a3d3c38e58b9d2dfb9207cab690b6310
# 63052  51eb2eebd5d76a24625b31c33dd41449  07a2a7e0f63fd8cb757ed77d4245623c
# 67697  88083e8f64d95b932164187484d90212  f67cd1a215aae2a1074638bbd35a223a
# ...

# %%
#nilai null pada order_delivered_carrier_date dengan status order delivered akan disi berdsarakan rata-rata waktu pengiriman
#sebelumnya akan dibuat nilai delivered_time
delivered_time = orders_dataset_df['order_delivered_customer_date'] - orders_dataset_df['order_delivered_carrier_date']
delivered_time = delivered_time.apply(lambda x: x.total_seconds())
orders_dataset_df['delivered_time'] = round(delivered_time/86400) #dikonversi kedalam hari

orders_dataset_df.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %%
#terdapat anomali pada nilai minimum delivered time yang menghasilkan nilai minus
orders_dataset_df[orders_dataset_df['delivered_time'] < 0].head()
# Out:
#                                order_id                       customer_id  \
# 6437   a1abeb653a4d4cd1e142ccb8c82cd069  5f50465da00b7fed5dd1239f4ecf6e2c
# 9553   383aa8b2724fe452d9ccd9934a8c628b  b1cb2f9d7a19480f3749e248db14d58f
# 13487  cb1134f9010d242e9515ad1c78ec0c39  2fd33ac77677bd214b1882868317eeed
# 14474  dceb62e8fa94b46006c9554fed743df0  2721900eb4e0f1cc2c836dd7bc1b1e11
# 21338  8c78d01de3a9009e23d6877a7cc9be20  6cd7106899e59a1fbd0622d5f1efedf4
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 6437     delivered      2017-07-20 11:20:52 2017-07-21 06:43:14
# 9553     delivered      2017-07-02 20:58:43 2017-07-02 21:10:20
# 13487    delivered      2017-07-16 12:35:34 2017-07-18 06:03:50
# 14474    delivered      2017-07-20 20:58:05 2017-07-22 11:45:11
# 21338    delivered      2016-10-08 15:36:50 2016-10-08 18:13:44
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 6437           2017-07-28 16:57:58           2017-07-25 19:32:56
# ...

# %%
#menyesuaikan order_delivered_customer_date dengan order_estimated_delivered_date agar tidak terdapat nilai minus
orders_dataset_df.loc[orders_dataset_df['delivered_time'] < 0, 'order_delivered_customer_date'] = orders_dataset_df['order_estimated_delivery_date']
#update delivered_time
delivered_time = orders_dataset_df['order_delivered_customer_date'] - orders_dataset_df['order_delivered_carrier_date']
delivered_time = delivered_time.apply(lambda x: x.total_seconds())
orders_dataset_df['delivered_time'] = round(delivered_time/86400) #dikonversi kedalam hari

orders_dataset_df.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %%
#mengisi data kosong pada order_delivered_carrier_date dengan mengurangi order_delivered_customer_date dengan rata-rata waktu pengiriman
orders_dataset_df.loc[orders_dataset_df['order_status'] == 'delivered', 'order_delivered_carrier_date'] = orders_dataset_df.loc[orders_dataset_df['order_status'] == 'delivered', 'order_delivered_carrier_date'].fillna(
    orders_dataset_df['order_delivered_customer_date'] - pd.to_timedelta(orders_dataset_df['delivered_time'].mean().round(), unit='days')
)
#mengupdate kembali delivered_time
delivered_time = orders_dataset_df['order_delivered_customer_date'] - orders_dataset_df['order_delivered_carrier_date']
delivered_time = delivered_time.apply(lambda x: x.total_seconds())
orders_dataset_df['delivered_time'] = round(delivered_time/86400)

orders_dataset_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   0
# order_delivered_carrier_date     1781
# order_delivered_customer_date    2957
# order_estimated_delivery_date       0
# order_approved_time               160
# delivered_time                   2957
# dtype: int64

# %%
# #menghapus kolom order_item_id 
# order_items_df = order_items_df.drop(columns=['order_item_id'], axis=1)
# order_items_df.head()

# %%
#mengubah jenis data menjadi datetime pada order_items
order_items_df['shipping_limit_date'] = pd.to_datetime(order_items_df['shipping_limit_date'])
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
#mengubah jenis data menjadi datetime pada order_reviews
datetime_columns = ['review_creation_date', 'review_answer_timestamp']

for column in datetime_columns:
    order_reviews_df[column] = pd.to_datetime(order_reviews_df[column])

order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
#menghapus data null pada products_dataset_df
products_dataset_df.dropna(inplace=True)
products_dataset_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Explore Data Customer

# %%
#merge data customer dengan geolocation
customer_geo_df = geolocation_df.rename(columns={'geolocation_zip_code_prefix': 'customer_zip_code_prefix', 'geolocation_lat':'customer_lat', 'geolocation_lng':'customer_lng'})
customer_df = pd.merge(
    customers_dataset_df,
    customer_geo_df,
    left_on='customer_zip_code_prefix',
    right_on='customer_zip_code_prefix',
    how='left'
)

customer_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 2  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 3  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 4  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
#
#    customer_zip_code_prefix customer_city customer_state  customer_lat  \
# 0                     14409        franca             SP    -20.509897
# 1                     14409        franca             SP    -20.497396
# 2                     14409        franca             SP    -20.510459
# 3                     14409        franca             SP    -20.480940
# 4                     14409        franca             SP    -20.515413
#
#    customer_lng
# 0    -47.397866
# 1    -47.399241
# 2    -47.399553
# 3    -47.394161
# 4    -47.398194

# %%
#bersarkan data di bawah didapati bahwa customer paling banyak bersal dari kota sao paulo
customer_df.groupby(by='customer_city').customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# ## Explor Data Order

# %%
# berdsarkan data di bawah didapati bahwa rata-rata waktu pengiriman adalah 9 hari 
# dengan minimum pengiriman pada hari yang sama dan maksimum adalah 205 hari
orders_dataset_df.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %%
'''
berdasarkan data di bawah didapati transaksi dengan berbagai status, yang mana status berhasil mencakup delivered, shipped, dan invoiced.
sedangkan status gagal mencakup canceled dan unavailable serta proses lainnya mencakup processing, created dan approved.
'''
orders_dataset_df.groupby(by='order_status').order_id.nunique().sort_values(ascending=False)
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_id, dtype: int64

# %%
order_items_merge = pd.merge(
    orders_dataset_df,
    order_items_df,
    on='order_id',
    how='left'
)

order_items_merge.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                             113425                            113425
# unique                             99441                             99441
# top     8272b63d03f5f79c56e9e4120aec44ef  fc3d1daec319d62d49bfb5e1f83123e9
# freq                                  21                                21
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %%
order_payments_merge = pd.merge(
    orders_dataset_df,
    order_payments_df,
    on='order_id',
    how='left'
)

order_payments_merge.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                             103887                            103887
# unique                             99441                             99441
# top     fa65dad1b0e818e3ccc5cb0e39231352  9af2372a1e49340278e7c1ef8d749f34
# freq                                  29                                29
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %%
order_merge = pd.merge(
    order_items_merge,
    order_payments_df,
    on='order_id',
    how='left'
)

order_merge.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                             118434                            118434
# unique                             99441                             99441
# top     895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# freq                                  63                                63
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %% [markdown]
# ## Explore Products and Sellers

# %%
#merge kolom product_dataset dengan product_category
product_merge_df = products_dataset_df.merge(product_category_df, on='product_category_name', how='left')
#hanya mengambil kolom product_id dan product_category
product_merge_df = product_merge_df[['product_id', 'product_category_name_english']]
product_merge_df.rename(columns={'product_category_name_english': 'product_category'}, inplace=True)
product_merge_df.head()
# Out:
#                          product_id product_category
# 0  1e9e8ef04dbcff4541ed26657ea517e5        perfumery
# 1  3aa071139cb16b67ca9e5dea641aaa2f              art
# 2  96bd76ec8810374ed1b65e291975717f   sports_leisure
# 3  cef67bcfe19066a932b7673e239eb23d             baby
# 4  9dc1a7de274444849c219cff195d0b71       housewares

# %%
order_payments_df.groupby(by='payment_type').order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
order_items_df.describe(include='all')
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN           2018-01-18
# 1                                                NaN           2018-03-10
# 2                                                NaN           2018-02-17
# ...

# %%
products_dataset_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...
